# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 30   73    Male  Average        UG        No
# 34   86    Male  Average    School        No
# 7    60  Female     Poor    School       Yes
# 29   83  Female  Average        UG       Yes
# 43   27    Male     Poor        PG        No

# %%
df=df.iloc[:,2:]

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df=pd.read_csv('customer.csv')
df=df.iloc[:,2:]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#      review education
# 24  Average        PG
# 28     Poor    School
# 34  Average    School
# 26     Poor        PG
# 4   Average        UG
# 31     Poor    School
# 7      Poor    School
# 47     Good        PG
# 21  Average        PG
# 37  Average        PG
# 30  Average        UG
# 16     Poor        UG
# 9      Good        UG
# 36     Good        UG
# 43     Poor        PG
# 32  Average        UG
# 11     Good        UG
# 17     Poor        UG
# 8   Average        UG
# 40     Good    School
# 33     Good        PG
# 12     Poor    School
# 39     Poor        PG
# 27     Poor        PG
# 41     Good        PG
# 10     Good        UG
# 0   Average    School
# 5   Average    School
# 15     Poor        UG
# 19     Poor        PG
# 23     Good    School
# 3      Good        PG
# 49     Good        UG
# 46     Poor        PG
# 1      Poor        UG
# 6      Good    School
# 14     Poor        PG
# 2      Good        PG
# 42     Good        PG
# 45     Poor        PG

# %%
from sklearn.preprocessing import OrdinalEncoder

# Initialize OrdinalEncoder with the correct categories
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# Use the string versions of X_train and X_test (X_train_str, X_test_str from kernel state)
# for fitting and transforming to ensure correct data types are used.
X_train_encoded = oe.fit_transform(X_train_str)
X_test_encoded = oe.transform(X_test_str)

# Update X_train and X_test with the newly encoded numerical arrays
X_train = X_train_encoded
X_test = X_test_encoded

# %%
X_train
# Out:
# array([[0., 0.],
#        [1., 1.],
#        [1., 2.],
#        [1., 1.],
#        [2., 2.],
#        [2., 0.],
#        [2., 2.],
#        [0., 2.],
#        [2., 2.],
#        [0., 1.],
#        [2., 1.],
#        [0., 1.],
#        [1., 2.],
#        [1., 0.],
#        [0., 0.],
#        [1., 0.],
#        [1., 1.],
#        [0., 2.],
#        [2., 2.],
#        [1., 0.],
#        [1., 1.],
#        [2., 1.],
#        [2., 1.],
#        [0., 1.],
#        [1., 2.],
#        [2., 2.],
#        [0., 2.],
#        [0., 0.],
#        [2., 0.],
#        [2., 0.],
#        [2., 1.],
#        [0., 2.],
#        [2., 0.],
#        [2., 1.],
#        [1., 0.],
#        [0., 0.],
#        [2., 2.],
#        [0., 2.],
#        [0., 0.],
#        [2., 0.]])

# %%
oe.categories_
# Out:
# [array(['Poor', 'Average', 'Good'], dtype=object),
#  array(['School', 'UG', 'PG'], dtype=object)]
