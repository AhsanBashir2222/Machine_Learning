# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('quiz1.csv', encoding='latin1' )
cleaned_df=df.copy()
cleaned_df.dropna(subset=['comment_id','user_name','comment_text','post_date','sentiment'],inplace=True)
value_to_fill={
    'comment_id' :'1',
    'user_name': 'Anonymous',
    'comment_text': 'Any_one',
    'post_date': '1/1/2003',
    'sentiment':'Positive',
}
cleaned_df.fillna(value_to_fill,inplace=True)
print(cleaned_df.isnull().sum())
cleaned_df.head(10)
# Out:
# comment_id      0
# user_name       0
# comment_text    0
# post_date       0
# sentiment       0
# dtype: int64
#    comment_id  user_name                                       comment_text  \
# 0           1    JohnDoe  "Wow! AMAZING product ?? Loved it! Check https...
# 1           2  JaneSmith      "The item was okay, but delivery was late ??"
# 3           4  MikeBrown  "Good value for money ?? Would recommend to fr...
# 5           6    SaraLee  "The quality is EXCELLENT! ?????? Visit http:/...
# 6           7   TomJones           "Not what I expected... disappointed ??"
# 7           8    AnnaKim  "Fast shipping!!! Product works perfectly ?? #...
# 8           9  BobWilson       "Mediocre experience. Could be better ?????"
# 9          10   LisaWang  "BROKEN item received! Very angry right now ??...
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative
# 7  1/17/2024  positive
# ...

# %% [markdown]
# **Lowercase**

# %%
string_col=['user_name','comment_text','post_date','sentiment']
df[string_col]=df[string_col].apply(lambda x: x.str.lower())
df.head()
# Out:
#    comment_id  user_name                                       comment_text  \
# 0           1    johndoe  "wow! amazing product ?? loved it! check https...
# 1           2  janesmith      "the item was okay, but delivery was late ??"
# 2           3        NaN  "terrible customer service!!! never buying aga...
# 3           4  mikebrown  "good value for money ?? would recommend to fr...
# 4           5        NaN                                                NaN
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 2  1/14/2024  negative
# 3  1/17/2024  positive
# 4  1/18/2024       NaN

# %% [markdown]
# **Remove all hyper link**

# %%
import re
url_pattern=re.compile(r'https?://\S+|www\.\S+')
cleaned_df['comment_text']=cleaned_df['comment_text'].str.replace(url_pattern,'',regex=True)
cleaned_df.head(10)
# Out:
#    comment_id  user_name                                       comment_text  \
# 0           1    JohnDoe  "Wow! AMAZING product ?? Loved it! Check  for ...
# 1           2  JaneSmith      "The item was okay, but delivery was late ??"
# 3           4  MikeBrown  "Good value for money ?? Would recommend to fr...
# 5           6    SaraLee  "The quality is EXCELLENT! ?????? Visit  #best...
# 6           7   TomJones           "Not what I expected... disappointed ??"
# 7           8    AnnaKim  "Fast shipping!!! Product works perfectly ?? #...
# 8           9  BobWilson       "Mediocre experience. Could be better ?????"
# 9          10   LisaWang  "BROKEN item received! Very angry right now ??...
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative
# 7  1/17/2024  positive
# 8  1/16/2024   neutral
# 9  1/14/2024  negative

# %% [markdown]
# **Remove email**

# %%
email_pattern = re.compile(r'\S+@\S+')
cleaned_df['comment_text'] = cleaned_df['comment_text'].apply(

    lambda text: email_pattern.sub('', text)

)
cleaned_df.head()
# Out:
#    comment_id  user_name                                       comment_text  \
# 0           1    JohnDoe  "Wow! AMAZING product ?? Loved it! Check  for ...
# 1           2  JaneSmith      "The item was okay, but delivery was late ??"
# 3           4  MikeBrown  "Good value for money ?? Would recommend to fr...
# 5           6    SaraLee  "The quality is EXCELLENT! ?????? Visit  #best...
# 6           7   TomJones           "Not what I expected... disappointed ??"
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative

# %%
hastag=re.compile(r'#')
cleaned_df['comment_text']=cleaned_df['comment_text'].str.replace(hastag,'',regex=True)
cleaned_df.head(10)
# Out:
#    comment_id  user_name                                       comment_text  \
# 0           1    JohnDoe  "Wow! AMAZING product ?? Loved it! Check  for ...
# 1           2  JaneSmith      "The item was okay, but delivery was late ??"
# 3           4  MikeBrown  "Good value for money ?? Would recommend to fr...
# 5           6    SaraLee  "The quality is EXCELLENT! ?????? Visit  bestp...
# 6           7   TomJones           "Not what I expected... disappointed ??"
# 7           8    AnnaKim  "Fast shipping!!! Product works perfectly ?? h...
# 8           9  BobWilson       "Mediocre experience. Could be better ?????"
# 9          10   LisaWang  "BROKEN item received! Very angry right now ??...
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative
# 7  1/17/2024  positive
# 8  1/16/2024   neutral
# 9  1/14/2024  negative

# %% [markdown]
# **Remove emoji**

# %%
emoji_pattern=re.compile(
    "["
    "\U0001F600-\U0001F64F"  # Emoticons
    "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
    "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
    "\U0001F700-\U0001F77F"  # Alchemical Symbols
    "]+", flags=re.UNICODE)

cleaned_df['comment_text']=cleaned_df['comment_text'].str.replace(emoji_pattern,'',regex=True)

cleaned_df.head()
# Out:
#    comment_id  user_name                                       comment_text  \
# 0           1    JohnDoe  "Wow! AMAZING product ?? Loved it! Check  for ...
# 1           2  JaneSmith      "The item was okay, but delivery was late ??"
# 3           4  MikeBrown  "Good value for money ?? Would recommend to fr...
# 5           6    SaraLee  "The quality is EXCELLENT! ?????? Visit  bestp...
# 6           7   TomJones           "Not what I expected... disappointed ??"
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative

# %% [markdown]
# **Advance text cleaning bold text**

# %%
def handle_repeat_punc(text):

  text=re.sub(r'(\?)+',r'?',text)
  text=re.sub(r'(\!)+',r'!',text)
  text=re.sub(r'(\.)+',r'.',text)
  return text

cleaned_df['comment_text']=cleaned_df['comment_text'].apply(handle_repeat_punc)
cleaned_df.head()
# Out:
#    comment_id  user_name                                       comment_text  \
# 0           1    JohnDoe  "Wow! AMAZING product ? Loved it! Check  for m...
# 1           2  JaneSmith       "The item was okay, but delivery was late ?"
# 3           4  MikeBrown  "Good value for money ? Would recommend to fri...
# 5           6    SaraLee   "The quality is EXCELLENT! ? Visit  bestproduct"
# 6           7   TomJones              "Not what I expected. disappointed ?"
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative

# %% [markdown]
# **Remove stopword**

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
def remove_stopword(text):
  words=text.split()
  filter_word=[word for word in words if word not in custom_stopword]
  return " ".join(filter_word)
cleaned_df['comment_text']=cleaned_df['comment_text'].apply(remove_stopword)
cleaned_df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    comment_id  user_name                                     comment_text  \
# 0           1    JohnDoe    "Wow! AMAZING product ? Loved it! Check more"
# 1           2  JaneSmith                 "The item okay, delivery late ?"
# 3           4  MikeBrown  "Good value money ? Would recommend to friends"
# 5           6    SaraLee  "The quality is EXCELLENT! ? Visit bestproduct"
# 6           7   TomJones            "Not what I expected. disappointed ?"
#
#    post_date sentiment
# 0  1/15/2024  positive
# 1  1/16/2024   neutral
# 3  1/17/2024  positive
# 5  1/16/2024  positive
# 6  1/15/2024  negative

# %% [markdown]
# **Stemming**

# %%
import nltk
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
word="Running"
stem=stemmer.stem(word)
print(f"Stemmed word :{stem}")
# Out:
# Stemmed word :run

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

text = "The cats were running faster than the dogs."

tokens = word_tokenize(text)

lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print(f"Original Text: {text}")
print(f"Lemmatized Words: {lemmatized_words}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Original Text: The cats were running faster than the dogs.
# Lemmatized Words: ['The', 'cat', 'were', 'running', 'faster', 'than', 'the', 'dog', '.']
